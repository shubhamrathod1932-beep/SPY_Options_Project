# %%
import pandas as pd
import yfinance as yf

# Download 1 year of SPY data
spy = yf.download("SPY", period="1y")

# Display first 5 rows
print(spy.head())

# Display information about the DataFrame
print("\nData Types:")
print(spy.dtypes)

print("\nSummary Statistics:")
print(spy.describe())

# Save the data
spy.to_csv("../data/historical/SPY_1Y.csv", index=False)

print("\nSPY data saved successfully!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2025-07-23  627.259827  627.259827  622.828881  624.628943  70511000
# 2025-07-24  627.467407  629.178489  627.042127  627.645427  71307100
# 2025-07-25  630.118042  630.592823  627.882860  628.130120  56865400
# 2025-07-28  629.959900  631.047821  628.575218  630.493960  54917100
# 2025-07-29  628.298279  631.670883  627.388378  631.354382  60556300
#
# Data Types:
# Price   Ticker
# Close   SPY       float64
# High    SPY       float64
# Low     SPY       float64
# Open    SPY       float64
# Volume  SPY         int64
# dtype: object
#
# Summary Statistics:
# Price        Close        High         Low        Open        Volume
# Ticker         SPY         SPY         SPY         SPY           SPY
# count   251.000000  251.000000  251.000000  251.000000  2.510000e+02
# mean    683.649721  686.678594  680.028503  683.563232  7.257610e+07
# std      37.079060   37.124494   36.858431   36.970878  2.414784e+07
# min     614.906616  619.476042  612.503254  618.813326  3.158190e+07
# 25%     657.381409  660.638170  653.426434  656.932603  5.590000e+07
# 50%     677.774719  680.303800  674.435916  677.887473  6.927380e+07
# 75%     707.607025  709.995904  704.135987  707.502335  8.623085e+07
# max     757.618225  758.446109  754.805464  756.201867  1.652935e+08
#
# SPY data saved successfully!
