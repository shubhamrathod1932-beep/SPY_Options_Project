# %%
import pandas as pd
import yfinance as yf

# Download 1 year of SPY data
spy = yf.download("SPY", period="1y")

# Display first 5 rows
print(spy.head())

# Display information about the DataFrame
print("\nData Types:")
print(spy.dtypes)

print("\nSummary Statistics:")
print(spy.describe())

# Save the data
spy.to_csv("../data/historical/SPY_1Y.csv", index=False)

print("\nSPY data saved successfully!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2025-08-06  625.845459  626.498200  621.246394  622.156295  64357500
# 2025-08-07  625.321228  629.999373  622.215625  629.267492  74205800
# 2025-08-08  630.197205  630.662085  626.794901  627.111401  64051600
# 2025-08-11  628.951050  631.947874  627.704848  630.474212  58742300
# 2025-08-12  635.646851  635.805071  629.811484  631.295045  64730800
#
# Data Types:
# Price   Ticker
# Close   SPY       float64
# High    SPY       float64
# Low     SPY       float64
# Open    SPY       float64
# Volume  SPY         int64
# dtype: object
#
# Summary Statistics:
# Price        Close        High         Low        Open        Volume
# Ticker         SPY         SPY         SPY         SPY           SPY
# count   251.000000  251.000000  251.000000  251.000000  2.510000e+02
# mean    688.502385  691.597855  684.773364  688.351390  7.171341e+07
# std      37.221566   37.317450   36.993963   37.140597  2.392036e+07
# min     625.321228  626.498200  621.246394  622.156295  3.158190e+07
# 25%     660.453186  665.312941  656.634836  661.588862  5.515360e+07
# 50%     679.609497  683.229105  676.405370  679.510347  6.835870e+07
# 75%     722.738068  727.939653  719.127337  723.102109  8.580825e+07
# max     771.330017  776.849976  769.510010  775.849976  1.652935e+08
#
# SPY data saved successfully!
