# %%
import os
import sys

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# c:\Users\HP\Documents\SPY_Options_Project

# %%
from src.greeks import vega

S = 727
K = 730
T = 30 / 365
r = 0.04
sigma = 0.22

print(vega(S, K, T, r, sigma))
# Out:
# 83.13528522973846

# %%
strikes = [700, 730, 760]

for strike in strikes:

    print(
        strike,
        vega(
            727,
            strike,
            30/365,
            0.04,
            0.22
        )
    )
# Out:
# 700 65.81907431332552
# 730 83.13528522973846
# 760 68.60284144407565
