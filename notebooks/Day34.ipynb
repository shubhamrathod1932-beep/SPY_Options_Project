# %%
import os
import sys

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# c:\Users\HP\Documents\SPY_Options_Project

# %%
from src.greeks import call_theta, put_theta

S = 727
K = 730
T = 30 / 365
r = 0.04
sigma = 0.22

print("Call Theta:", call_theta(S, K, T, r, sigma))
print("Put Theta :", put_theta(S, K, T, r, sigma))
# Out:
# Call Theta: -0.34327657304452563
# Put Theta : -0.26353915486529084

# %%
strikes = [700, 730, 760]

for strike in strikes:

    print(
        strike,
        call_theta(
            727,
            strike,
            30/365,
            0.04,
            0.22
        )
    )
# Out:
# 700 -0.29735009700478277
# 730 -0.34327657304452563
# 760 -0.27206718389734247
