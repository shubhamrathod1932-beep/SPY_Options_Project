# %%
import math
import numpy as np

# SPY prices
prices = np.array([730, 731, 729, 735, 728])

print("Average Price:", prices.mean())
print("Highest Price:", prices.max())
print("Lowest Price:", prices.min())
print("Standard Deviation:", prices.std())

print("Square Root of 25:", math.sqrt(25))
print("Natural Log of 10:", math.log(10))
print("Value of e:", math.exp(1))
# Out:
# Average Price: 730.6
# Highest Price: 735
# Lowest Price: 728
# Standard Deviation: 2.4166091947189146
# Square Root of 25: 5.0
# Natural Log of 10: 2.302585092994046
# Value of e: 2.718281828459045
