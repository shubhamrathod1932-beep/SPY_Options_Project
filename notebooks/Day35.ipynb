# %%
import os
import sys

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# c:\Users\Intern Batch 2\Documents\SPY_Options_Project

# %%
from src.greeks import call_rho, put_rho

S = 727
K = 730
T = 30 / 365
r = 0.04
sigma = 0.22

print("Call Rho:", call_rho(S, K, T, r, sigma))
print("Put Rho :", put_rho(S, K, T, r, sigma))
# Out:
# Call Rho: 0.28835395401613484
# Put Rho : -0.3096766823281264

# %%
strikes = [700, 730, 760]

for strike in strikes:

    print(
        strike,
        call_rho(
            727,
            strike,
            30/365,
            0.04,
            0.22
        )
    )
# Out:
# 700 0.42010118391941886
# 730 0.28835395401613484
# 760 0.15392573951798805
