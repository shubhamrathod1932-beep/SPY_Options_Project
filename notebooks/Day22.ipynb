# %%
import pandas as pd
import numpy as np

# Load SPY data
df = pd.read_csv("../data/historical/SPY_1Y.csv")

# If needed, flatten MultiIndex column names
if isinstance(df.columns, pd.MultiIndex):
    df.columns = [col[0] for col in df.columns]

# Calculate returns
df["Simple Return"] = df["Close"].pct_change()
df["Log Return"] = np.log(df["Close"] / df["Close"].shift(1))

# Display first 10 rows
print(df[["Close", "Simple Return", "Log Return"]].head(10))

# Remove NaN values
df = df.dropna()

# Summary statistics
print("\nSummary Statistics:")
print(df[["Simple Return", "Log Return"]].describe())

# Save the updated data
df.to_csv("../data/historical/SPY_Returns.csv", index=False)

print("\nSPY returns saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       8 if isinstance(df.columns, pd.MultiIndex):
#       9     df.columns = [col[0] for col in df.columns]
#      10
#      11 # Calculate returns
# ---> 12 df["Simple Return"] = df["Close"].pct_change()
#      13 df["Log Return"] = np.log(df["Close"] / df["Close"].shift(1))
#      14
#      15 # Display first 10 rows
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:11573, in NDFrame.pct_change(self, periods, fill_method, freq, **kwargs)
#   11569
#   11570         axis = self._get_axis_number(kwargs.pop("axis", "index"))
#   11571         shifted = self.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   11572         # Unsupported left operand type for / ("Self")
# > 11573         rs = self / shifted - 1  # type: ignore[operator]
#   11574         if freq is not None:
#   11575             # Shift method is implemented differently when freq is not None
#   11576             # We want to restore the original index
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arraylike.py:214, in OpsMixin.__truediv__(self, other)
#     212 @unpack_zerodim_and_defer("__truediv__")
#     213 def __truediv__(self, other):
# --> 214     return self._arith_method(other, operator.truediv)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:6751, in Series._arith_method(self, other, op)
#    6749 def _arith_method(self, other, op):
#    6750     self, other = self._align_for_op(other)
# -> 6751     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\base.py:1644, in IndexOpsMixin._arith_method(self, other, op)
#    1641     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1643 with np.errstate(all="ignore"):
# -> 1644     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1646 return self._construct_result(result, name=res_name, other=other)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\array_ops.py:279, in arithmetic_op(left, right, op)
#     270 right = ensure_wrapped_if_datetimelike(right)
#     272 if (
#     273     should_extension_dispatch(left, right)
#     274     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    277     # Timedelta/Timestamp and other custom scalars are included in the check
#     278     # because numexpr will fail on it, see GH#31457
# --> 279     res_values = op(left, right)
#     280 else:
#     281     # TODO we should handle EAs consistently and move this check before the if/else
#     282     # (https://github.com/pandas-dev/pandas/issues/41165)
#     283     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arraylike.py:214, in OpsMixin.__truediv__(self, other)
#     212 @unpack_zerodim_and_defer("__truediv__")
#     213 def __truediv__(self, other):
# --> 214     return self._arith_method(other, operator.truediv)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\string_.py:1218, in StringArray._cmp_method(self, other, op)
#    1216 result = np.empty_like(self._ndarray, dtype="object")
#    1217 result[mask] = self.dtype.na_value
# -> 1218 result[valid] = op(self._ndarray[valid], other)
#    1219 if isinstance(other, Path):
#    1220     # GH#61940
#    1221     return result
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
import yfinance as yf
import pandas as pd
import numpy as np

spy = yf.download("SPY", period="1y", auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy.columns = spy.columns.get_level_values(0)

# %%
print(spy.columns)
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='str', name='Price')

# %%
import numpy as np

# Calculate Simple Return
spy["Simple Return"] = spy["Close"].pct_change()

# Calculate Log Return
spy["Log Return"] = np.log(spy["Close"] / spy["Close"].shift(1))

# Display first 10 rows
print(spy[["Close", "Simple Return", "Log Return"]].head(10))
# Out:
# Price            Close  Simple Return  Log Return
# Date
# 2025-08-06  625.845459            NaN         NaN
# 2025-08-07  625.321289      -0.000838   -0.000838
# 2025-08-08  630.197205       0.007797    0.007767
# 2025-08-11  628.951050      -0.001977   -0.001979
# 2025-08-12  635.646851       0.010646    0.010590
# 2025-08-13  637.822754       0.003423    0.003417
# 2025-08-14  637.882080       0.000093    0.000093
# 2025-08-15  636.388611      -0.002341   -0.002344
# 2025-08-18  636.250183      -0.000218   -0.000218
# 2025-08-19  632.798401      -0.005425   -0.005440

# %%
spy = spy.dropna()

# %%
print(spy[["Simple Return", "Log Return"]].describe())
# Out:
# Price  Simple Return  Log Return
# count     250.000000  250.000000
# mean        0.000861    0.000828
# std         0.008125    0.008126
# min        -0.027028   -0.027400
# 25%        -0.003213   -0.003218
# 50%         0.001255    0.001254
# 75%         0.005656    0.005640
# max         0.029068    0.028653

# %%
spy.to_csv("../data/historical/SPY_Returns.csv", index=True)

# %%
import numpy as np

# Calculate Simple Returns
spy["Simple Return"] = spy["Close"].pct_change()

# Calculate Log Returns
spy["Log Return"] = np.log(spy["Close"] / spy["Close"].shift(1))

# Display first 10 rows
print(spy[["Close", "Simple Return", "Log Return"]].head(10))

# Remove the first NaN row
spy = spy.dropna()

# Summary Statistics
print("\nSummary Statistics:")
print(spy[["Simple Return", "Log Return"]].describe())

# Save the updated data
spy.to_csv("../data/historical/SPY_Returns.csv", index=True)

print("\nSPY returns saved successfully!")
# Out:
# Price            Close  Simple Return  Log Return
# Date
# 2025-08-07  625.321289            NaN         NaN
# 2025-08-08  630.197205       0.007797    0.007767
# 2025-08-11  628.951050      -0.001977   -0.001979
# 2025-08-12  635.646851       0.010646    0.010590
# 2025-08-13  637.822754       0.003423    0.003417
# 2025-08-14  637.882080       0.000093    0.000093
# 2025-08-15  636.388611      -0.002341   -0.002344
# 2025-08-18  636.250183      -0.000218   -0.000218
# 2025-08-19  632.798401      -0.005425   -0.005440
# 2025-08-20  631.117004      -0.002657   -0.002661
#
# Summary Statistics:
# Price  Simple Return  Log Return
# count     249.000000  249.000000
# mean        0.000868    0.000835
# std         0.008141    0.008142
# min        -0.027028   -0.027400
# 25%        -0.003223   -0.003229
# 50%         0.001358    0.001357
# 75%         0.005676    0.005660
# max         0.029068    0.028653
#
# SPY returns saved successfully!

# %%
spy = spy.dropna()

# %%
spy.head()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2025-08-08  630.197205  630.662085  626.794901  627.111401  64051600
# 2025-08-11  628.951050  631.947874  627.704848  630.474212  58742300
# 2025-08-12  635.646851  635.805071  629.811484  631.295045  64730800
# 2025-08-13  637.822754  639.108495  635.636951  637.842494  60092800
# 2025-08-14  637.882080  638.544721  635.300697  635.745717  59327500
#
# Price       Simple Return  Log Return
# Date
# 2025-08-08       0.007797    0.007767
# 2025-08-11      -0.001977   -0.001979
# 2025-08-12       0.010646    0.010590
# 2025-08-13       0.003423    0.003417
# 2025-08-14       0.000093    0.000093
