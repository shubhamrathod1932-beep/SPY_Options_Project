# %%
import os
import sys

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# c:\Users\Intern Batch 2\Documents\SPY_Options_Project

# %%
from src.option_pricing import black_scholes_call
from src.option_pricing import black_scholes_put

from src.greeks import call_delta
from src.greeks import put_delta
from src.greeks import gamma

print(black_scholes_call(730,730,30/365,0.04,0.20))

print(call_delta(730,730,30/365,0.04,0.20))

print(gamma(730,730,30/365,0.04,0.20))
# Out:
# 17.89421412704496
# 0.5342697035912677
# 0.009495912851666516

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Intern Batch 2\Documents\SPY_Options_Project\notebooks
