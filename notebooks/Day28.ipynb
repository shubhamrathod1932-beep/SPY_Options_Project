# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

# %%
calls = pd.read_csv("../data/options/SPY_Calls.csv")

# %%
option = calls.iloc[63]

print(option)
# Out:
# contractSymbol              SPY260806C00770000
# lastTradeDate        2026-08-06 16:20:39+00:00
# strike                                   770.0
# lastPrice                                 0.37
# bid                                       0.37
# ask                                       0.38
# change                                   -2.37
# percentChange                       -86.181816
# volume                                284965.0
# openInterest                              6232
# impliedVolatility                     0.063486
# inTheMoney                               False
# contractSize                           REGULAR
# currency                                   USD
# Name: 63, dtype: object

# %%
S = 738.25
K = option["strike"]

sigma = option["impliedVolatility"]

market_price = option["lastPrice"]

T = 1 / 365

r = 0.04

# %%
def black_scholes_call(S, K, T, r, sigma):

    d1 = (
        np.log(S / K)
        + (r + sigma**2 / 2) * T
    ) / (sigma * np.sqrt(T))

    d2 = d1 - sigma * np.sqrt(T)

    return (
        S * norm.cdf(d1)
        - K * np.exp(-r * T) * norm.cdf(d2)
    )

# %%
theoretical_price = black_scholes_call(
    S,
    K,
    T,
    r,
    sigma
)

print(theoretical_price)
# Out:
# 1.2649886661032947e-37

# %%
pricing_error = market_price - theoretical_price

print(pricing_error)
# Out:
# 0.37

# %%
if pricing_error > 0:
    print("Market price is above theoretical price.")

elif pricing_error < 0:
    print("Market price is below theoretical price.")

else:
    print("Market price equals theoretical price.")
# Out:
# Market price is above theoretical price.

# %%
print(market_price)
# Out:
# 0.37
